# %% [markdown]
# How to store Data in python?
# Lists, sets, and dictionaries are the most common ways to store data

# %% [markdown]
# 1.Lists

# %% [markdown]
# initialization of lists
#
#
#
#
# list=[element1, element2, …, elementn]

# %%
numbers=[0,1,2,3]

# %%
#empty list
numbers=[] #Empty lists do not contain any values within the square brackets.

# %%
primes = [2, 3, 5, 7, 11]
print(primes)
# Out:
# [2, 3, 5, 7, 11]

# %%
#Adding Lists Together
items = ['cake', 'cookie', 'bread']
total_items = items + ['biscuit', 'tart']
print(total_items)
# Out:
# ['cake', 'cookie', 'bread', 'biscuit', 'tart']

# %%
total_items = items + ['biscuit']

# %%
total_items
# Out:
# ['cake', 'cookie', 'bread', 'biscuit']

# %%
numbers = [1, 2, 3, 4, 10]
names = ['Jenny', 'Sam', 'Alexis']
mixed = ['Jenny', 1, 2]
list_of_lists = [['a', 1], ['b', 2]]

# %%
#List Method .append()# append(new_element)
orders = ['daisies', 'periwinkle']
orders.append('tulips')
print(orders)
# Out:
# ['daisies', 'periwinkle', 'tulips']

# %%
orders.insert(-2,'tulips')#list.insert(position, element)
print(orders)
# Out:
# ['daisies', 'periwinkle', 'tulips', 'tulips', 'tulips']

# %%
numbers = [0, 1, 2, 3, 4]

# %%
numbers[2] = 10
numbers
# Out:
# [0, 1, 10, 3, 4]

# %%
numbers.insert(5, 3)
numbers
# Out:
# [0, 1, 10, 3, 4, 3, 2, 2]

# %%
number = [0, 1, 2, 3, 4]
letters = ['a','b','c']
number.append(letters)

# %%
number
# Out:
# [0, 1, 2, 3, 4, ['a', 'b', 'c']]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# List Indices
# Python list elements are ordered by index, a number referring to their placement in the list. List indices start at 0 and increment by one.

# %%
#Zero-Indexing
names = ['Roger', 'Rafael', 'Andy', 'Novak']

# %%
names[0]
# Out:
# 'Roger'

# %%
#List Indices
berries = ["blueberry", "cranberry", "raspberry"]

berries[0]  
berries[2]
# Out:
# 'raspberry'

# %%
#Negative List Indices
soups = ['minestrone', 'lentil', 'pho', 'laksa']
soups[-1]
# Out:
# 'laksa'

# %%
soups[-3:]
# Out:
# ['lentil', 'pho', 'laksa']

# %%
soups[:-2]
# Out:
# ['minestrone', 'lentil']

# %% [markdown]
# #Slicing on Lists

# %%
a = ['Hello', 1, 4.63, True, "World", 2.0, "False"]

# %%
a[2 : 5]
# Out:
# [4.63, True, 'World']

# %%
a[ : ]
# Out:
# ['Hello', 1, 4.63, True, 'World', 2.0, 'False']

# %%
# Replace our existing data item with a new value.
a[1] = 2
a
# Out:
# ['Hello', 2, 4.63, True, 'World', 2.0, 'False']

# %% [markdown]
# Merge Two Lists

# %%
list1 = [1, 2, 4, 6]
list2 = [9, 3, 19, 7]
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 4, 6, 9, 3, 19, 7]

# %%
#Interchange First and Last Element of a List
list5 = [1, 29, 51, 9, 17, 6, 7, 23]
list5[0], list5[-1] = list5[-1], list5[0]
print(list5)
# Out:
# [23, 29, 51, 9, 17, 6, 7, 1]

# %%
# A 2D list of names and hobbies
class_name_hobbies = [["Jenny", "Breakdancing"], ["Alexus", "Photography"], ["Grace", "Soccer"]]
#Modifying 2D Lists
# The sublist of Jenny is at index 0. The hobby is at index 1 of the sublist. 
class_name_hobbies[0][1] = "Meditation"
print(class_name_hobbies)
# Out:
# [['Jenny', 'Meditation'], ['Alexus', 'Photography'], ['Grace', 'Soccer']]

# %%
#Accessing 2D Lists

# %%
# 2D list of people's heights
heights = [["Noelle", 61], ["Ali", 70], ["Sam", 67]]
# Access the sublist at index 0, and then access the 1st index of that sublist. 
noelles_height = heights[0][1] 
print(noelles_height)
# Out:
# 61

# %%
#List Method .remove()
# Create a list
shopping_line = ["Cole", "Kip", "Chris", "Sylvana", "Chris"]
 
# Removes the first occurance of "Chris"
shopping_line.remove("Chris")#the first occurrence of the element is removed.
print(shopping_line)
# Out:
# ['Cole', 'Kip', 'Sylvana', 'Chris']

# %%
number = [0, 1, 2, 3, 4]
number.pop(4)
number
# Out:
# [0, 1, 2, 3]
